# %%
# Step - 1 ( Importing libraries )

import pandas as pd   # For importing data from csv file
import numpy as np    # For mathemtical operation
import matplotlib.pyplot as plt  # For visulization
import seaborn as sns

# %%
# Step - 2 ( Data loading )

# Link to download data : https://drive.google.com/file/d/1Zvjgv_-2FDi9QtuxT_lzZMLVV05eSYRs/view?usp=sharing
data = pd.read_csv("insurance.csv")
data
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
# ...

# %%
# step- 3 ( EDA -  Exploratory Data Analysis )

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
# ...

# %%
# If you want to check top 20 data

data.head(20)
# Out:
#      age   sex    bmi  children smoker  Claim_Amount  past_consultations  \
# 0   18.0  male  23.21       0.0     no  29087.543130                17.0
# 1   18.0  male  30.14       0.0     no  39053.674370                 7.0
# 2   18.0  male  33.33       0.0     no  39023.627590                19.0
# 3   18.0  male  33.66       0.0     no  28185.393320                11.0
# 4   18.0  male  34.10       0.0     no  14697.859410                16.0
# 5   18.0  male  34.43       0.0     no  26488.339120                20.0
# 6   18.0  male  37.29       0.0     no  33217.365480                13.0
# 7   18.0  male  41.14       0.0     no  46770.585330                12.0
# 8   18.0  male  43.01       0.0     no   9715.650411                17.0
# 9   18.0  male  53.13       0.0     no  17046.585150                19.0
# 10  19.0  male  19.80       0.0     no  16980.214030                 2.0
# 11  19.0  male  20.30       0.0     no   1920.136268                 NaN
# ...

# %%
# If you want to check bottom 50 data

data.tail(50)
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 1288  36.0    male  41.895       3.0    yes   59787.34328                36.0
# 1289  56.0    male  31.790       2.0    yes   56423.84945                29.0
# 1290  42.0  female  40.370       2.0    yes   47328.33284                25.0
# 1291  56.0    male  33.630       0.0    yes   35726.45214                19.0
# 1292  34.0  female  30.210       1.0    yes   34217.55681                35.0
# 1293  47.0    male  38.940       2.0    yes   46520.24790                23.0
# 1294  54.0    male  34.210       2.0    yes   42578.49702                24.0
# 1295  51.0  female  38.060       0.0    yes   34887.41326                30.0
# 1296  55.0  female  35.200       0.0    yes   29807.41386                33.0
# 1297  22.0    male  52.580       1.0    yes   58019.55109                26.0
# 1298  29.0    male  35.500       2.0    yes   29567.96081                28.0
# ...

# %%
# I want to display the full data all rows and all columns
print(data.to_string())
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  Anual_Salary     region       charges
# 0     18.0    male  23.210       0.0     no  29087.543130                17.0      715428.0          4.720921e+06                              0.0  5.578497e+07  southeast   1121.873900
# 1     18.0    male  30.140       0.0     no  39053.674370                 7.0      699157.0          4.329832e+06                              0.0  1.370089e+07  southeast   1131.506600
# 2     18.0    male  33.330       0.0     no  39023.627590                19.0      702341.0          6.884861e+06                              0.0  7.352311e+07  southeast   1135.940700
# 3     18.0    male  33.660       0.0     no  28185.393320                11.0      700250.0          4.274774e+06                              0.0  7.581968e+07  southeast   1136.399400
# ...

# %%
# step - 4 ( Data Analysis )

'''
Check for null value / Missing values
Check for duplicate data
Check for outliers
'''
# Out:
# '\nCheck for null value / Missing values\nCheck for duplicate data\nCheck for outliers\n'

# %%
# Check for null values   ( True means Null value is present in that cell , False means No null value)
data.isnull()
# Out:
#         age    sex    bmi  children  smoker  Claim_Amount  past_consultations  \
# 0     False  False  False     False   False         False               False
# 1     False  False  False     False   False         False               False
# 2     False  False  False     False   False         False               False
# 3     False  False  False     False   False         False               False
# 4     False  False  False     False   False         False               False
# ...     ...    ...    ...       ...     ...           ...                 ...
# 1333  False  False  False     False   False         False               False
# 1334  False  False  False     False   False         False               False
# 1335  False  False  False     False   False         False               False
# 1336  False  False  False     False   False         False               False
# 1337  False  False  False     False   False         False               False
#
# ...

# %%
data.isnull().sum()  # To display the total no of null values in each and every column
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
data.isnull().sum().sum()  # Total 52 null value sare there in data
# Out:
# 52

# %%
# Percentage of Null values out of total data
Percentage = (52/1338) *100
print(" We are having :" , Percentage  , " percentage of Null values")
# Out:
#  We are having : 3.8863976083707024  percentage of Null values

# %%
data.shape # No of rows , No of columns
# Out:
# (1338, 13)

# %% [markdown]
# **How to deal will these Null values**
#
# **1) When to drop the Null value data  = If the size of Null values is less than 30% of your data .**
#
# **2) When to replace the Null values = If the size of Null values is more than 30% of your data .**

# %%
# Drop the Null values as the count is less than 30%
data.dropna(inplace=True)   # Why inplace=True because i want to make changes in data

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.shape # No of rows , No of columns
# Out:
# (1287, 13)

# %%
# Check for duplicate records   # True means that row is having duplicate data similar to some other row
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1287, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
# Check for Outliers by using Boxplot to identity in which column outliers are there

# Create a list to contain all the columns names
col = list(data.columns)
col
# Out:
# ['age',
#  'sex',
#  'bmi',
#  'children',
#  'smoker',
#  'Claim_Amount',
#  'past_consultations',
#  'num_of_steps',
#  'Hospital_expenditure',
#  'NUmber_of_past_hospitalizations',
#  'Anual_Salary',
#  'region',
#  'charges']

# %%
# Box plot you can only draw for Numerical columns

for i in col :
  if (data[i].dtypes=="int64" or data[i].dtypes=="float64") :
    plt.boxplot(data[i])
    plt.xlabel(i)
    plt.show()

# %%
'''
Column names in which outliers are there

bmi
past consultants
No of past hospilitazion
Past consultancy
Anual salary

DONT REMOVE ANY OUTLIER FROM TARGET COLUMNS ( charges )
'''
# Out:
# '\nColumn names in which outliers are there\n\nbmi\npast consultants\nNo of past hospilitazion\nPast consultancy\nAnual salary\n\nDONT REMOVE ANY OUTLIER FROM TARGET COLUMNS ( charges )\n'

# %%
col
# Out:
# ['age',
#  'sex',
#  'bmi',
#  'children',
#  'smoker',
#  'Claim_Amount',
#  'past_consultations',
#  'num_of_steps',
#  'Hospital_expenditure',
#  'NUmber_of_past_hospitalizations',
#  'Anual_Salary',
#  'region',
#  'charges']

# %% [markdown]
# **How to fix these columns**
#
# We are going to consider that data in these columns which is present inside Upper Fence and Lower Fence

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Q1 = data.bmi.quantile(0.25)
Q3 = data.bmi.quantile(0.75)
IQR =  Q3-Q1     # Inter Quantile Range
UF = Q3+1.5*IQR
LF = Q1-1.5*IQR
# Consider only the data in the column present inside Upper and lower fence
data = data[ ( data.bmi >= LF ) & (data.bmi <=UF)]


Q1 = data.past_consultations.quantile(0.25)
Q3 = data.past_consultations.quantile(0.75)
IQR =  Q3-Q1     # Inter Quantile Range
UF = Q3+1.5*IQR
LF = Q1-1.5*IQR
# Consider only the data in the column present inside Upper and lower fence
data = data[ ( data.past_consultations >= LF ) & (data.past_consultations <=UF)]


Q1 = data.NUmber_of_past_hospitalizations.quantile(0.25)
Q3 = data.NUmber_of_past_hospitalizations.quantile(0.75)
IQR =  Q3-Q1     # Inter Quantile Range
UF = Q3+1.5*IQR
LF = Q1-1.5*IQR
# Consider only the data in the column present inside Upper and lower fence
data = data[ ( data.NUmber_of_past_hospitalizations >= LF ) & (data.NUmber_of_past_hospitalizations <=UF)]

Q1 = data.Anual_Salary.quantile(0.25)
Q3 = data.Anual_Salary.quantile(0.75)
IQR =  Q3-Q1     # Inter Quantile Range
UF = Q3+1.5*IQR
LF = Q1-1.5*IQR
# Consider only the data in the column present inside Upper and lower fence
data = data[ ( data.Anual_Salary >= LF ) & (data.Anual_Salary <=UF)]

# %%
for i in col :
  if (data[i].dtypes=="int64" or data[i].dtypes=="float64") :
    plt.boxplot(data[i])
    plt.xlabel(i)
    plt.show()

# %%
data.shape  # we have remove the outlier data now we are left with only 851 rows data
# Out:
# (851, 13)

# %%
data
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 151   25.0    male  27.550       0.0     no   39148.95495                10.0
# 152   22.0  female  20.235       0.0     no   41547.52536                13.0
# 153   25.0    male  35.625       0.0     no   39660.60193                12.0
# 154   20.0    male  31.130       2.0     no   16032.87148                 7.0
# 155   21.0  female  17.400       1.0     no   31090.98977                21.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1036  43.0    male  20.130       2.0    yes   44184.65414                19.0
# 1041  24.0  female  27.600       0.0     no   27184.27803                 9.0
# 1046  29.0  female  27.940       1.0    yes   51168.25474                23.0
# 1048  31.0    male  25.900       3.0    yes   46619.40230                27.0
# 1050  31.0    male  29.810       0.0    yes   24382.58056                21.0
#
# ...

# %% [markdown]
# **We are having some categorical values in our data**
#
# **We need to use Encoding to convert those categorical values to numerical values**

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
# Condition to select only object data type column so we can convert these values to numerical value
for i in col:
  if data[i].dtypes=="object":  # select only object data type column
    data[i]=le.fit_transform(data[i])  # Apply label encoding to those columns

# %%
data

'''
male = 1
female = 0

no smoker = 0
yes smoker = 1


'''
# Out:
# '\nmale = 1\nfemale = 0\n\nno smoker = 0\nyes smoker = 1\n\n\n'

# %% [markdown]
# # Linear Regression Machine Learning Model Building

# %%
# step -1 ( Dividing the data into Independent variable and dependent varible)

x=data.iloc[:, :-1 ]    # Independent variables

y=data["charges"]       # Dependent variable

# We are going to use independent variable to predict the value of dependent variable

# %%
x
# Out:
#        age  sex     bmi  children  smoker  Claim_Amount  past_consultations  \
# 151   25.0    1  27.550       0.0       0   39148.95495                10.0
# 152   22.0    0  20.235       0.0       0   41547.52536                13.0
# 153   25.0    1  35.625       0.0       0   39660.60193                12.0
# 154   20.0    1  31.130       2.0       0   16032.87148                 7.0
# 155   21.0    0  17.400       1.0       0   31090.98977                21.0
# ...    ...  ...     ...       ...     ...           ...                 ...
# 1036  43.0    1  20.130       2.0       1   44184.65414                19.0
# 1041  24.0    0  27.600       0.0       0   27184.27803                 9.0
# 1046  29.0    0  27.940       1.0       1   51168.25474                23.0
# 1048  31.0    1  25.900       3.0       1   46619.40230                27.0
# 1050  31.0    1  29.810       0.0       1   24382.58056                21.0
#
# ...

# %%
y
# Out:
# 151      2523.16950
# 152      2527.81865
# 153      2534.39375
# 154      2566.47070
# 155      2585.26900
#            ...
# 1036    18767.73770
# 1041    18955.22017
# 1046    19107.77960
# 1048    19199.94400
# 1050    19350.36890
# Name: charges, Length: 851, dtype: float64

# %%
# Data splitting into Training data and Testing data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.model_selection import train_test_split

# Divide the data into 80:20 ( 80% data for Training and 20% data for Testing)
x_train , x_test , y_train , y_test = train_test_split ( x , y , test_size =0.20 ,random_state = 0)

# random_state will follow pattern to select some random values

# %%
'''
Train means Training
Test means Testing

x means Independent variable
y means Dependent variable

x_train = Independent variable of Training data
y_train = Dependent variable of Training data

x_test = Independent variable of Testing data  ( age , bmi , no of steps etc )
y_test = Dependent variable of Testing data  ( charges )

'''
# Out:
# '\nTrain means Training\nTest means Testing\n\nx means Independent variable\ny means Dependent variable\n\nx_train = Independent variable of Training data\ny_train = Dependent variable of Training data\n\nx_test = Independent variable of Testing data  ( age , bmi , no of steps etc )\ny_test = Dependent variable of Testing data  ( charges )\n\n'

# %%
# Build our Linear Regression model to predict charges
from sklearn.linear_model import LinearRegression

# %%
# Give a name to your model and define which model it is
my_model =  LinearRegression()

# %%
# Training the model
my_model.fit(x_train , y_train)  # Giving both question and answer to student for exam preparation
# Out:
# LinearRegression()

# %%
# Test the model

# A question paper is going to be there with Indepndent variable of testing
model_answer = my_model.predict(x_test)

# %%
x_test  # Independent variable of testing data
# Out:
#        age  sex     bmi  children  smoker  Claim_Amount  past_consultations  \
# 848   56.0    0  26.600       1.0       0   43993.29455                23.0
# 504   42.0    0  32.870       0.0       0   28351.15966                18.0
# 719   47.0    0  33.915       3.0       0   44544.86046                 9.0
# 1024  21.0    1  25.700       4.0       1   23327.30277                14.0
# 860   58.0    0  36.480       0.0       0   27369.02461                22.0
# ...    ...  ...     ...       ...     ...           ...                 ...
# 311   23.0    0  34.960       3.0       0   43210.04994                 2.0
# 895   59.0    1  29.700       2.0       0   12770.13249                24.0
# 799   58.0    1  38.000       0.0       0   33893.25137                21.0
# 201   28.0    0  33.400       0.0       0   19040.96490                21.0
# 999   19.0    1  26.030       1.0       1   30825.19007                11.0
#
# ...

# %%
model_answer  # Predicted charges values by my model
# Out:
# array([12127.83617076,  6398.69183059, 10325.78383631, 16782.31599986,
#        12003.03334411, 11953.51689034,  2935.57622062, 12423.42006076,
#        15988.69767219,  4679.24354834, 17812.47729594,  8559.9217075 ,
#        11922.05788398,  8810.89881292, 12484.48473353, 14370.16199547,
#        15875.19450305,  8229.37605123,  8769.57574865, 13250.75859482,
#         9264.50338044,  9454.3252722 , 11202.90155406,  4002.02512628,
#        12241.32278805,  8078.56983307,  2892.98643642,  5614.52455389,
#         5360.53302304, 11189.43974111,  3994.85000748, 11761.65852171,
#        11872.4864434 ,  8772.80808603,  4634.00201389,  5030.64314825,
#         2523.95054424,  7440.4660601 ,  2368.72718471,  8310.036927  ,
#        11203.18669062,  3666.79084454, 11535.31241471, 13660.63140722,
#        11959.10681672,  7974.98344591,  9394.21554402, 16721.01950488,
#         2568.60660371, 12557.11226761,  5363.19659012, 12888.7913797 ,
# ...

# %%
y_test # Actual charges values
# Out:
# 848     12044.34200
# 504      7050.02130
# 719     10115.00885
# 1024    17942.10600
# 860     12235.83920
#            ...
# 311      4466.62140
# 895     12925.88600
# 799     11365.95200
# 201      3172.01800
# 999     16450.89470
# Name: charges, Length: 171, dtype: float64

# %%
# Evaluate the performance of model
from sklearn.metrics import *

result = r2_score( y_test  , model_answer)*100
result
# Out:
# 95.63738873945124

# %%
# Draw a Best fit line to compare how close the actual and predictec charges values are
sns.regplot( x=model_answer   , y= y_test)
plt.xlabel ("Predicted Charges values")
plt.ylabel ("Actual charges values")
plt.title("Best fit line of Linear Regression Model")
plt.show()
